# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras

# %%
# !pip install --upgrade tensorflow
from tensorflow.keras import models

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path("/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Test")

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed = 123,
    validation_split = 0.2,
    subset = 'training',
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed = 123,
    validation_split = 0.2,
    subset = 'validation',
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (12,12))
for images, labels in train_ds.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        image = plt.imread(str(list(data_dir_train.glob(class_names[i] + '/*.jpg'))[1]))
        plt.title(class_names[i])
        plt.imshow(image)
### your code goes here, you can use training or validation data to visualize

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here


num_classes = 9

model = Sequential([
    layers.experimental.preprocessing.Rescaling(1./255,
                          input_shape = (img_height, img_width,3)),
    layers.Conv2D(16,3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3989801 (15.22 MB)
# Trainable params: 3989801 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 335s 1s/step - loss: 1.8066 - accuracy: 0.3371 - val_loss: 1.6104 - val_accuracy: 0.4385
# Epoch 2/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.5202 - accuracy: 0.4749 - val_loss: 1.4859 - val_accuracy: 0.4452
# Epoch 3/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.3361 - accuracy: 0.5279 - val_loss: 1.3085 - val_accuracy: 0.5369
# Epoch 4/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.2656 - accuracy: 0.5424 - val_loss: 1.3508 - val_accuracy: 0.5526
# Epoch 5/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.1839 - accuracy: 0.5742 - val_loss: 1.7368 - val_accuracy: 0.4116
# Epoch 6/20
# 56/56 [==============================] - 1s 20ms/step - loss: 1.1599 - accuracy: 0.5898 - val_loss: 1.3056 - val_accuracy: 0.5638
# Epoch 7/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.9550 - accuracy: 0.6585 - val_loss: 1.4639 - val_accuracy: 0.5503
# Epoch 8/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.8583 - accuracy: 0.6914 - val_loss: 1.4180 - val_accuracy: 0.5257
# Epoch 9/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.7516 - accuracy: 0.7416 - val_loss: 1.4860 - val_accuracy: 0.5414
# Epoch 10/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.6914 - accuracy: 0.7528 - val_loss: 1.7495 - val_accuracy: 0.4989
# Epoch 11/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.6273 - accuracy: 0.7807 - val_loss: 1.6940 - val_accuracy: 0.5235
# Epoch 12/20
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4806 - accuracy: 0.8242 - val_loss: 2.1033 - val_accuracy: 0.5436
# Epoch 13/20
# 56/56 [==============================] - 1s 20ms/step - loss: 0.4586 - accuracy: 0.8343 - val_loss: 1.8520 - val_accuracy: 0.5570
# Epoch 14/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.3870 - accuracy: 0.8527 - val_loss: 1.8641 - val_accuracy: 0.5772
# Epoch 15/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.3637 - accuracy: 0.8666 - val_loss: 2.0557 - val_accuracy: 0.5078
# Epoch 16/20
# 56/56 [==============================] - 1s 20ms/step - loss: 0.3265 - accuracy: 0.8778 - val_loss: 2.0345 - val_accuracy: 0.5638
# Epoch 17/20
# 56/56 [==============================] - 1s 20ms/step - loss: 0.2529 - accuracy: 0.9102 - val_loss: 2.0331 - val_accuracy: 0.5660
# Epoch 18/20
# 56/56 [==============================] - 1s 20ms/step - loss: 0.2284 - accuracy: 0.9074 - val_loss: 2.1609 - val_accuracy: 0.5638
# Epoch 19/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.1948 - accuracy: 0.9280 - val_loss: 2.2930 - val_accuracy: 0.5302
# Epoch 20/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.2091 - accuracy: 0.9085 - val_loss: 2.1166 - val_accuracy: 0.5436

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# 1.   The occurrence of overfitting is evident as there is a discernible difference in the loss functions between the training and test sets around the 10-11th epoch.
# 2.   The accuracy hovers around 75-80%, suggesting that there are an adequate number of features for the model to capture the underlying pattern

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here

data_augumentation = keras.Sequential([
    layers.experimental.preprocessing.RandomFlip(mode = 'horizontal_and_vertical', input_shape = (img_height, img_width,3)),
    layers.experimental.preprocessing.RandomRotation(0.2, fill_mode = 'reflect'),
    layers.experimental.preprocessing.RandomZoom(height_factor = (0.2, 0.3), width_factor = (0.2,0.3), fill_mode = 'reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

plt.figure(figsize = (12,12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(data_augumentation(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here

num_classes = 9

model = Sequential([data_augumentation,
    layers.experimental.preprocessing.Rescaling(1./255,
                          input_shape = (img_height, img_width,3)),
    layers.Conv2D(16,3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here

model.compile(optimizer='adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics = ['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs

epochs = 20
history = model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 3s 27ms/step - loss: 2.0255 - accuracy: 0.2573 - val_loss: 1.8367 - val_accuracy: 0.3311
# Epoch 2/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.7686 - accuracy: 0.3633 - val_loss: 1.7110 - val_accuracy: 0.4362
# Epoch 3/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.5361 - accuracy: 0.4570 - val_loss: 1.4269 - val_accuracy: 0.5324
# Epoch 4/20
# 56/56 [==============================] - 1s 24ms/step - loss: 1.4433 - accuracy: 0.4911 - val_loss: 1.4225 - val_accuracy: 0.5145
# Epoch 5/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.4174 - accuracy: 0.4989 - val_loss: 1.4450 - val_accuracy: 0.4966
# Epoch 6/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.3398 - accuracy: 0.5151 - val_loss: 1.4640 - val_accuracy: 0.4832
# Epoch 7/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.3170 - accuracy: 0.5346 - val_loss: 1.3314 - val_accuracy: 0.5190
# Epoch 8/20
# 56/56 [==============================] - 2s 27ms/step - loss: 1.2590 - accuracy: 0.5519 - val_loss: 1.3308 - val_accuracy: 0.5235
# Epoch 9/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.2882 - accuracy: 0.5340 - val_loss: 1.3360 - val_accuracy: 0.5503
# Epoch 10/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.2409 - accuracy: 0.5379 - val_loss: 1.4801 - val_accuracy: 0.4653
# Epoch 11/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.2223 - accuracy: 0.5569 - val_loss: 1.3956 - val_accuracy: 0.5101
# Epoch 12/20
# 56/56 [==============================] - 1s 24ms/step - loss: 1.2470 - accuracy: 0.5525 - val_loss: 1.3214 - val_accuracy: 0.5436
# Epoch 13/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.1778 - accuracy: 0.5714 - val_loss: 1.2660 - val_accuracy: 0.5638
# Epoch 14/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.1968 - accuracy: 0.5664 - val_loss: 1.2785 - val_accuracy: 0.5481
# Epoch 15/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.1391 - accuracy: 0.5993 - val_loss: 1.2829 - val_accuracy: 0.5503
# Epoch 16/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.1804 - accuracy: 0.5904 - val_loss: 1.3320 - val_accuracy: 0.5660
# Epoch 17/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.1919 - accuracy: 0.5737 - val_loss: 1.5738 - val_accuracy: 0.4877
# Epoch 18/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.2068 - accuracy: 0.5681 - val_loss: 1.4041 - val_accuracy: 0.5324
# Epoch 19/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.1479 - accuracy: 0.5904 - val_loss: 1.3528 - val_accuracy: 0.5369
# Epoch 20/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.1203 - accuracy: 0.5848 - val_loss: 1.3564 - val_accuracy: 0.5570

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# 1. While the accuracy remains unchanged, it is  evident that the overfitting issue has been addressed through data augmentation.
#
# 2. It is premature to draw conclusions as we can enhance accuracy by extending the number of epochs.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.

from glob import glob
path_list = []
lesion_list = []

for i in class_names:
    for j in data_dir_train.glob(i + "/*.jpg"):
        path_list.append(str(j))
        lesion_list.append(i)

dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()), columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 1     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 2     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 3     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# 4     /content/gdrive/MyDrive/CNN_assignment/Skin ca...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2235  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2236  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2237  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
# 2238  /content/gdrive/MyDrive/CNN_assignment/Skin ca...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
original_df[['Label']].value_counts()
# Out:
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# dtype: int64

# %%
count = []
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+"/*.jpg"))))

plt.figure(figsize = (22,10))
plt.bar(class_names, count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# Answer 1 - **Seborrheic keratosis** has least number of samples
#
# Answer 2 - **Pigmented benign keratosis** dominates in terms of proportionate number of samples

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.23.5)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
path_to_training_dataset=str(data_dir_train) + '/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x78799A127430>: 100%|██████████| 500/500 [00:18<00:00, 26.49 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x78799A1777F0>: 100%|██████████| 500/500 [00:18<00:00, 26.72 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x78799A280850>: 100%|██████████| 500/500 [00:18<00:00, 26.64 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x787A1A744A00>: 100%|██████████| 500/500 [01:24<00:00,  5.91 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x787A1B8C9C90>: 100%|██████████| 500/500 [01:24<00:00,  5.88 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x78799E623970>: 100%|██████████| 500/500 [00:17<00:00, 28.47 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x78799A2E4E50>: 100%|██████████| 500/500 [00:39<00:00, 12.58 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x78799E7CE320>: 100%|██████████| 500/500 [00:19<00:00, 25.45 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x787A1B8FE860>: 100%|██████████| 500/500 [00:18<00:00, 27.56 Samples/s]

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]


path_list[:5]
# Out:
# ['/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030463.jpg',
#  '/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029025.jpg',
#  '/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029141.jpg',
#  '/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027536.jpg',
#  '/content/gdrive/MyDrive/CNN_assignment/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029460.jpg']

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new[:5]
# Out:
# ['basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma',
#  'basal cell carcinoma']

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
# Out:
# <ipython-input-35-17a6b079869a>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: Label, dtype: int64

# %%
new_df.shape
# Out:
# (6739, 2)

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
#data_dir_train1 = pathlib.Path("/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output")

# %%
#data_dir_train1
# Out:
# PosixPath('/content/gdrive/MyDrive/Skin cancer ISIC The International Skin Imaging Collaboration/Train/output')

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
#data_dir_train="path to directory with training data + data created using augmentor"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = "validation",
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here

num_classes = 9

model = Sequential([data_augumentation,
    layers.experimental.preprocessing.Rescaling(1./255,
                          input_shape = (img_height, img_width,3)),
    layers.Conv2D(16,3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32,3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64,3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation = 'relu'),
    layers.Dense(num_classes)
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here

model.compile(optimizer='adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
              metrics = ['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 50
## Your code goes here, use 50 epochs.
history = model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = epochs
)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 45s 242ms/step - loss: 2.0369 - accuracy: 0.2083 - val_loss: 1.7447 - val_accuracy: 0.3185
# Epoch 2/50
# 169/169 [==============================] - 41s 235ms/step - loss: 1.6399 - accuracy: 0.3765 - val_loss: 1.6041 - val_accuracy: 0.3994
# Epoch 3/50
# 169/169 [==============================] - 44s 250ms/step - loss: 1.4732 - accuracy: 0.4351 - val_loss: 1.4455 - val_accuracy: 0.4269
# Epoch 4/50
# 169/169 [==============================] - 40s 227ms/step - loss: 1.3885 - accuracy: 0.4722 - val_loss: 1.3740 - val_accuracy: 0.4677
# Epoch 5/50
# 169/169 [==============================] - 40s 231ms/step - loss: 1.3491 - accuracy: 0.4811 - val_loss: 1.4209 - val_accuracy: 0.4729
# Epoch 6/50
# 169/169 [==============================] - 42s 243ms/step - loss: 1.3450 - accuracy: 0.4855 - val_loss: 1.3620 - val_accuracy: 0.4788
# Epoch 7/50
# 169/169 [==============================] - 40s 232ms/step - loss: 1.2896 - accuracy: 0.5015 - val_loss: 1.3085 - val_accuracy: 0.4900
# Epoch 8/50
# 169/169 [==============================] - 40s 227ms/step - loss: 1.2653 - accuracy: 0.5147 - val_loss: 1.3016 - val_accuracy: 0.5011
# Epoch 9/50
# 169/169 [==============================] - 43s 242ms/step - loss: 1.2199 - accuracy: 0.5276 - val_loss: 1.2985 - val_accuracy: 0.4929
# Epoch 10/50
# 169/169 [==============================] - 39s 227ms/step - loss: 1.2532 - accuracy: 0.5152 - val_loss: 1.2569 - val_accuracy: 0.5048
# Epoch 11/50
# 169/169 [==============================] - 39s 226ms/step - loss: 1.1710 - accuracy: 0.5469 - val_loss: 1.3091 - val_accuracy: 0.5145
# Epoch 12/50
# 169/169 [==============================] - 40s 229ms/step - loss: 1.1679 - accuracy: 0.5449 - val_loss: 1.1926 - val_accuracy: 0.5271
# Epoch 13/50
# 169/169 [==============================] - 40s 227ms/step - loss: 1.1305 - accuracy: 0.5618 - val_loss: 1.3415 - val_accuracy: 0.4959
# Epoch 14/50
# 169/169 [==============================] - 41s 237ms/step - loss: 1.1297 - accuracy: 0.5608 - val_loss: 1.1922 - val_accuracy: 0.5367
# Epoch 15/50
# 169/169 [==============================] - 39s 224ms/step - loss: 1.0434 - accuracy: 0.5927 - val_loss: 1.1548 - val_accuracy: 0.5531
# Epoch 16/50
# 169/169 [==============================] - 39s 222ms/step - loss: 1.0364 - accuracy: 0.5959 - val_loss: 1.1640 - val_accuracy: 0.5657
# Epoch 17/50
# 169/169 [==============================] - 39s 223ms/step - loss: 1.0443 - accuracy: 0.5924 - val_loss: 1.0796 - val_accuracy: 0.5724
# Epoch 18/50
# 169/169 [==============================] - 43s 248ms/step - loss: 0.9822 - accuracy: 0.6094 - val_loss: 1.1267 - val_accuracy: 0.5857
# Epoch 19/50
# 169/169 [==============================] - 39s 227ms/step - loss: 0.9833 - accuracy: 0.6161 - val_loss: 1.1139 - val_accuracy: 0.5761
# Epoch 20/50
# 169/169 [==============================] - 40s 230ms/step - loss: 0.9508 - accuracy: 0.6256 - val_loss: 1.1228 - val_accuracy: 0.5709
# Epoch 21/50
# 169/169 [==============================] - 39s 223ms/step - loss: 0.9260 - accuracy: 0.6378 - val_loss: 1.0723 - val_accuracy: 0.5813
# Epoch 22/50
# 169/169 [==============================] - 40s 229ms/step - loss: 0.9052 - accuracy: 0.6478 - val_loss: 1.1078 - val_accuracy: 0.5754
# Epoch 23/50
# 167/169 [============================>.] - ETA: 0s - loss: 0.8788 - accuracy: 0.6572Epoch 24/50
# 169/169 [==============================] - 42s 242ms/step - loss: 0.8861 - accuracy: 0.6541 - val_loss: 1.0383 - val_accuracy: 0.6028
# Epoch 25/50
# 169/169 [==============================] - 39s 223ms/step - loss: 0.8513 - accuracy: 0.6766 - val_loss: 1.0384 - val_accuracy: 0.6221
# Epoch 26/50
# 169/169 [==============================] - 39s 227ms/step - loss: 0.8120 - accuracy: 0.6834 - val_loss: 1.0306 - val_accuracy: 0.6199
# Epoch 27/50
# 169/169 [==============================] - 40s 230ms/step - loss: 0.8394 - accuracy: 0.6723 - val_loss: 1.0560 - val_accuracy: 0.6117
# Epoch 28/50
# 169/169 [==============================] - 40s 229ms/step - loss: 0.7937 - accuracy: 0.6907 - val_loss: 1.0039 - val_accuracy: 0.6474
# Epoch 29/50
# 169/169 [==============================] - 40s 228ms/step - loss: 0.8161 - accuracy: 0.6855 - val_loss: 1.1234 - val_accuracy: 0.5976
# Epoch 30/50
# 169/169 [==============================] - 40s 228ms/step - loss: 0.7656 - accuracy: 0.7014 - val_loss: 1.0828 - val_accuracy: 0.6162
# Epoch 31/50
# 169/169 [==============================] - 43s 245ms/step - loss: 0.7559 - accuracy: 0.7079 - val_loss: 1.0045 - val_accuracy: 0.6503
# Epoch 32/50
# 169/169 [==============================] - 40s 229ms/step - loss: 0.7422 - accuracy: 0.7105 - val_loss: 0.9628 - val_accuracy: 0.6399
# Epoch 33/50
# 169/169 [==============================] - 43s 241ms/step - loss: 0.7347 - accuracy: 0.7187 - val_loss: 0.9590 - val_accuracy: 0.6555
# Epoch 34/50
# 169/169 [==============================] - 39s 223ms/step - loss: 0.6844 - accuracy: 0.7352 - val_loss: 0.9906 - val_accuracy: 0.6451
# Epoch 35/50
# 169/169 [==============================] - 39s 227ms/step - loss: 0.7000 - accuracy: 0.7294 - val_loss: 0.9685 - val_accuracy: 0.6540
# Epoch 36/50
# 169/169 [==============================] - 42s 239ms/step - loss: 0.6598 - accuracy: 0.7415 - val_loss: 1.1156 - val_accuracy: 0.6399
# Epoch 37/50
# 169/169 [==============================] - 39s 222ms/step - loss: 0.6652 - accuracy: 0.7392 - val_loss: 1.0107 - val_accuracy: 0.6518
# Epoch 38/50
# 169/169 [==============================] - 41s 234ms/step - loss: 0.6889 - accuracy: 0.7430 - val_loss: 1.0477 - val_accuracy: 0.6407
# Epoch 39/50
# 169/169 [==============================] - 41s 236ms/step - loss: 0.6284 - accuracy: 0.7565 - val_loss: 1.0619 - val_accuracy: 0.6333
# Epoch 40/50
# 169/169 [==============================] - 40s 230ms/step - loss: 0.6611 - accuracy: 0.7379 - val_loss: 0.9470 - val_accuracy: 0.6763
# Epoch 41/50
# 169/169 [==============================] - 39s 226ms/step - loss: 0.6039 - accuracy: 0.7650 - val_loss: 1.0394 - val_accuracy: 0.6548
# Epoch 42/50
# 169/169 [==============================] - 39s 226ms/step - loss: 0.6104 - accuracy: 0.7641 - val_loss: 1.0195 - val_accuracy: 0.6719
# Epoch 43/50
# 169/169 [==============================] - 39s 224ms/step - loss: 0.6444 - accuracy: 0.7519 - val_loss: 0.9517 - val_accuracy: 0.6763
# Epoch 44/50
# 169/169 [==============================] - 43s 242ms/step - loss: 0.5900 - accuracy: 0.7700 - val_loss: 0.9171 - val_accuracy: 0.6941
# Epoch 45/50
# 169/169 [==============================] - 40s 230ms/step - loss: 0.5860 - accuracy: 0.7767 - val_loss: 0.9644 - val_accuracy: 0.6875
# Epoch 46/50
# 169/169 [==============================] - 39s 226ms/step - loss: 0.5793 - accuracy: 0.7761 - val_loss: 0.9341 - val_accuracy: 0.6949
# Epoch 47/50
# 169/169 [==============================] - 40s 228ms/step - loss: 0.5690 - accuracy: 0.7778 - val_loss: 0.9457 - val_accuracy: 0.6919
# Epoch 48/50
# 169/169 [==============================] - 39s 226ms/step - loss: 0.5563 - accuracy: 0.7839 - val_loss: 0.9995 - val_accuracy: 0.6785
# Epoch 49/50
# 169/169 [==============================] - 39s 222ms/step - loss: 0.5605 - accuracy: 0.7834 - val_loss: 0.9826 - val_accuracy: 0.6763
# Epoch 50/50
# 169/169 [==============================] - 39s 225ms/step - loss: 0.5465 - accuracy: 0.7899 - val_loss: 1.0462 - val_accuracy: 0.6837

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# *   In the final model, there is slight sign of underfitting/overfitting.
#
# *   There is a slight improvement in model performance
# *   After 50 epochs, the model has 79% training accuracy and 68% validation accuracy, it can be said that the model is able to almost predict well.
